# %%
import matplotlib.pyplot as plt
import numpy as np
import dkist 
import astropy.units as u
from astropy.visualization import AsinhStretch, ImageNormalize

# %%
old_TiO_dset = dkist.load_dataset("../../data/pid_1_123/BNRPZ/")

# %%
new_TiO_dset = dkist.load_dataset("../../data/pid_1_123_new/FMKCWI/")

# %%
old_TiO_dset.meta["headers"]["FIDO_CFG"][0]
# Out:
# np.str_('OUT_C-BS643_C-BS555_C-BS950_C-W1_C-W3')

# %%
old_TiO_dset.meta["headers"][["CDELT1", "CDELT2"]]
# Out:
# <Table length=432>
#        CDELT1               CDELT2
#       float64              float64
# -------------------- --------------------
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
#                  ...                  ...
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# ...

# %%
new_TiO_dset.meta["headers"][["CDELT1", "CDELT2"]]
# Out:
# <Table length=432>
#        CDELT1               CDELT2
#       float64              float64
# -------------------- --------------------
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
#                  ...                  ...
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# 0.015498150140047073 0.015498150140047073
# ...

# %%
old_TiO_dset[0,:,:].plot()
# Out:
# <WCSAxes: >

# %%
new_TiO_dset[0,:,:].plot()
# Out:
# <WCSAxes: >

# %%
new_TiO_dset.data[0,1024,1024].compute()
# Out:
# np.float32(26049.945)

# %%
old_TiO_dset.data[0,1024,1024].compute()
# Out:
# np.float32(26049.139)

# %%
np.nanmean(old_TiO_dset.data[0,:,:]).compute()
# Out:
# np.float32(25581.588)

# %%
np.nanmean(new_TiO_dset.data[0,:,:]).compute()
# Out:
# np.float32(25581.582)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(10,5), layout="constrained")
ax1.imshow(old_TiO_dset.data[0,1024:1024+512,1024:1024+512], origin="lower", interpolation="none")
ax2.imshow(new_TiO_dset.data[0,1024:1024+512,1024:1024+512], origin="lower", interpolation="none")

# %%
fig, ax = plt.subplots(layout="constrained")
ax.imshow(
    old_TiO_dset.data[0,1024:1024+512,1024:1024+512]/new_TiO_dset.data[0,1024:1024+512,1024:1024+512] - 1,
    origin="lower", interpolation="none",
    cmap="bwr"
)

# %%
np.nanmin(old_TiO_dset.data[0,1024:1024+512,1024:1024+512]/new_TiO_dset.data[0,1024:1024+512,1024:1024+512] - 1).compute()
# Out:
# np.float32(0.0)
